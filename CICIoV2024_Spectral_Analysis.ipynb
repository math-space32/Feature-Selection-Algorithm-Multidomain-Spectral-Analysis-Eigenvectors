# %% [markdown]
# # CICIoV2024

# %% [markdown]
# ## Loading the dataset

# %%
import pandas as pd

benign_file = pd.read_csv("/content/drive/MyDrive/IoV/decimal_benign.csv")
dos_file = pd.read_csv("/content/drive/MyDrive/IoV/decimal_DoS.csv")
gas_file = pd.read_csv("/content/drive/MyDrive/IoV/decimal_spoofing-GAS.csv")
rpm_file = pd.read_csv("/content/drive/MyDrive/IoV/decimal_spoofing-RPM.csv")
speed_file = pd.read_csv("/content/drive/MyDrive/IoV/decimal_spoofing-SPEED.csv")
steering_file = pd.read_csv("/content/drive/MyDrive/IoV/decimal_spoofing-STEERING_WHEEL.csv")
benign_file.drop("label", axis=1, inplace=True)
benign_file.drop("category", axis=1, inplace=True)
benign_file.replace('BENIGN', 0, inplace=True)
dos_file.drop("label", axis=1, inplace=True)
dos_file.drop("category", axis=1, inplace=True)
dos_file.replace('DoS', 1, inplace=True)
gas_file.drop("label", axis=1, inplace=True)
gas_file.drop("category", axis=1, inplace=True)
gas_file.replace('GAS', 2, inplace=True)
rpm_file.drop("label", axis=1, inplace=True)
rpm_file.drop("category", axis=1, inplace=True)
rpm_file.replace('RPM', 3, inplace=True)
speed_file.drop("label", axis=1, inplace=True)
speed_file.drop("category", axis=1, inplace=True)
speed_file.replace('SPEED', 4, inplace=True)
steering_file.drop("label", axis=1, inplace=True)
steering_file.drop("category", axis=1, inplace=True)
steering_file.replace('STEERING_WHEEL', 5, inplace=True)
benign_file.rename(columns={'specific_class':'Label'}, inplace=True)
dos_file.rename(columns={'specific_class':'Label'}, inplace=True)
gas_file.rename(columns={'specific_class':'Label'}, inplace=True)
rpm_file.rename(columns={'specific_class':'Label'}, inplace=True)
speed_file.rename(columns={'specific_class':'Label'}, inplace=True)
steering_file.rename(columns={'specific_class':'Label'}, inplace=True)
# Out:
# <ipython-input-2-fcc1aa0c2fcb>:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   benign_file.replace('BENIGN', 0, inplace=True)
# <ipython-input-2-fcc1aa0c2fcb>:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dos_file.replace('DoS', 1, inplace=True)
# <ipython-input-2-fcc1aa0c2fcb>:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gas_file.replace('GAS', 2, inplace=True)
# <ipython-input-2-fcc1aa0c2fcb>:20: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   rpm_file.replace('RPM', 3, inplace=True)
# <ipython-input-2-fcc1aa0c2fcb>:23: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   speed_file.replace('SPEED', 4, inplace=True)
# <ipython-input-2-fcc1aa0c2fcb>:26: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   steering_file.replace('STEERING_WHEEL', 5, inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(benign_file, benign_file['Label'] , test_size = 0.3, random_state=42)
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(dos_file, dos_file['Label'] , test_size = 0.3, random_state=42)
X_train_3, X_test_3, y_train_3, y_test_3 = train_test_split(gas_file, gas_file['Label'] , test_size = 0.3, random_state=42)
X_train_4, X_test_4, y_train_4, y_test_4 = train_test_split(rpm_file, rpm_file['Label'] , test_size = 0.3, random_state=42)
X_train_5, X_test_5, y_train_5, y_test_5 = train_test_split(speed_file, speed_file['Label'] , test_size = 0.3, random_state=42)
X_train_6, X_test_6, y_train_6, y_test_6 = train_test_split(steering_file, steering_file['Label'] , test_size = 0.3, random_state=42)

# %%
inter = pd.concat([y_train_1, y_train_2, y_train_3, y_train_4, y_train_5, y_train_6], ignore_index=True)

# %% [markdown]
# ## Data Visualization

# %%
values = inter.value_counts()
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.pie(values, labels = ['Benign', 'Dos', 'GAS', 'RPM', 'SPEED', 'STEERING_WHEEL'], autopct='%3.1f%%')
plt.axis('equal')
plt.title('CICIoV2024')
plt.show()

# %%
X_train_1.drop("Label", axis=1, inplace=True)
X_test_1.drop("Label", axis=1, inplace=True)

X_train_2.drop("Label", axis=1, inplace=True)
X_test_2.drop("Label", axis=1, inplace=True)

X_train_3.drop("Label", axis=1, inplace=True)
X_test_3.drop("Label", axis=1, inplace=True)

X_train_4.drop("Label", axis=1, inplace=True)
X_test_4.drop("Label", axis=1, inplace=True)

X_train_5.drop("Label", axis=1, inplace=True)
X_test_5.drop("Label", axis=1, inplace=True)

X_train_6.drop("Label", axis=1, inplace=True)
X_test_6.drop("Label", axis=1, inplace=True)

# %%
X_train = pd.concat([X_train_1, X_train_2, X_train_3, X_train_4, X_train_5, X_train_6], ignore_index=True)

# %%
X_test = pd.concat([X_test_1, X_test_2, X_test_3, X_test_4, X_test_5, X_test_6], ignore_index=True)

# %%
y_train = pd.concat([y_train_1, y_train_2, y_train_3, y_train_4, y_train_5, y_train_6], ignore_index=True)

# %%
y_test = pd.concat([y_test_1, y_test_2, y_test_3, y_test_4, y_test_5, y_test_6], ignore_index=True)

# %%
from sklearn.preprocessing import StandardScaler

standard_scaler_scaling = StandardScaler()
scaled_data = standard_scaler_scaling.fit_transform(X_train)

for i in range(len(scaled_data[0])):
    print(scaled_data[0][i], " ", X_train.columns[i])
# Out:
# -0.06519661295724609   ID
# 1.3595080729622733   DATA_0
# -0.7318027357535891   DATA_1
# 0.9617769976060168   DATA_2
# -0.6367937270755483   DATA_3
# -0.7025960872001471   DATA_4
# -0.5719481905814927   DATA_5
# -0.7059998408573048   DATA_6
# -0.6034188415606849   DATA_7

# %%
X_train = pd.DataFrame(scaled_data, columns = X_train.columns)

# %%
X_train
# Out:
#               ID    DATA_0    DATA_1    DATA_2    DATA_3    DATA_4    DATA_5  \
# 0      -0.065197  1.359508 -0.731803  0.961777 -0.636794 -0.702596 -0.571948
# 1      -0.521152 -0.618904  0.397982 -0.756264 -0.636794 -0.702596 -0.571948
# 2       2.056392  2.067690 -0.731803  1.003010 -0.636794  1.282837 -0.571948
# 3       1.674879 -0.349121 -0.397052 -0.687543 -0.415468 -0.702596 -0.232957
# 4       0.071280 -0.798760 -0.417974 -0.756264 -0.636794 -0.407883 -0.571948
# ...          ...       ...       ...       ...       ...       ...       ...
# 985745 -1.268671  1.381990 -0.721342 -0.728776 -0.249474 -0.330327 -0.518981
# 985746 -1.268671  1.381990 -0.721342 -0.728776 -0.249474 -0.330327 -0.518981
# 985747 -1.268671  1.381990 -0.721342 -0.728776 -0.249474 -0.330327 -0.518981
# 985748 -1.268671  0.685049 -0.700420 -0.728776 -0.249474 -0.330327 -0.518981
# 985749 -1.268671  0.685049 -0.700420 -0.728776 -0.249474 -0.330327 -0.518981
#
#           DATA_6    DATA_7
# 0      -0.706000 -0.603419
# 1      -0.706000 -0.603419
# 2      -0.312796  1.816359
# 3      -0.302966 -0.603419
# 4      -0.706000 -0.603419
# ...          ...       ...
# 985745  0.650554 -0.263450
# 985746  0.650554 -0.263450
# 985747  0.650554 -0.263450
# 985748  0.650554 -0.263450
# 985749  0.650554 -0.263450
#
# [985750 rows x 9 columns]

# %% [markdown]
# ## Standard Scaling

# %%
standard_scaler_scaling = StandardScaler()
scaled_data = standard_scaler_scaling.fit_transform(X_test)

for i in range(len(scaled_data[0])):
    print(scaled_data[0][i], " ", X_test.columns[i])
# Out:
# -0.5598603207162843   ID
# -0.6195881283660838   DATA_0
# -0.05303372969923542   DATA_1
# -0.7553984457290916   DATA_2
# -0.6345046113431914   DATA_3
# -0.7024409969785192   DATA_4
# -0.5693778774607681   DATA_5
# -0.7046246994014792   DATA_6
# -0.6018765664891745   DATA_7

# %%
X_test = pd.DataFrame(scaled_data, columns = X_test.columns)

# %%
X_test
# Out:
#               ID    DATA_0    DATA_1    DATA_2    DATA_3    DATA_4    DATA_5  \
# 0      -0.559860 -0.619588 -0.053034 -0.755398 -0.634505 -0.702441 -0.569378
# 1       1.572375 -0.799330 -0.733227 -0.425663  2.125472 -0.469638  2.137874
# 2      -0.497877 -0.788096  1.642218 -0.645487 -0.634505  1.563511 -0.526911
# 3      -1.297465  2.065304  1.935225 -0.549314  2.191978  1.268626  2.137874
# 4      -1.300564 -0.102831  0.606231  0.151373  0.784279 -0.469638  2.137874
# ...          ...       ...       ...       ...       ...       ...       ...
# 422464 -1.269572  0.683540 -0.701834 -0.727921 -0.246556 -0.329956 -0.516295
# 422465 -1.269572  1.380039 -0.722763 -0.727921 -0.246556 -0.329956 -0.516295
# 422466 -1.269572  0.683540 -0.701834 -0.727921 -0.246556 -0.329956 -0.516295
# 422467 -1.269572  1.380039 -0.722763 -0.727921 -0.246556 -0.329956 -0.516295
# 422468 -1.269572  0.683540 -0.701834 -0.727921 -0.246556 -0.329956 -0.516295
#
#           DATA_6    DATA_7
# 0      -0.704625 -0.601877
# 1      -0.556973  1.951619
# 2      -0.704625 -0.601877
# 3       1.805447  1.951619
# 4      -0.704625 -0.601877
# ...          ...       ...
# 422464  0.653767 -0.261410
# 422465  0.653767 -0.261410
# 422466  0.653767 -0.261410
# 422467  0.653767 -0.261410
# 422468  0.653767 -0.261410
#
# [422469 rows x 9 columns]

# %%
import math

# %%
data_scaled_frame = pd.concat([X_train, y_train], axis=1)

# %%
data_scaled_frame
# Out:
#               ID    DATA_0    DATA_1    DATA_2    DATA_3    DATA_4    DATA_5  \
# 0      -0.065197  1.359508 -0.731803  0.961777 -0.636794 -0.702596 -0.571948
# 1      -0.521152 -0.618904  0.397982 -0.756264 -0.636794 -0.702596 -0.571948
# 2       2.056392  2.067690 -0.731803  1.003010 -0.636794  1.282837 -0.571948
# 3       1.674879 -0.349121 -0.397052 -0.687543 -0.415468 -0.702596 -0.232957
# 4       0.071280 -0.798760 -0.417974 -0.756264 -0.636794 -0.407883 -0.571948
# ...          ...       ...       ...       ...       ...       ...       ...
# 985745 -1.268671  1.381990 -0.721342 -0.728776 -0.249474 -0.330327 -0.518981
# 985746 -1.268671  1.381990 -0.721342 -0.728776 -0.249474 -0.330327 -0.518981
# 985747 -1.268671  1.381990 -0.721342 -0.728776 -0.249474 -0.330327 -0.518981
# 985748 -1.268671  0.685049 -0.700420 -0.728776 -0.249474 -0.330327 -0.518981
# 985749 -1.268671  0.685049 -0.700420 -0.728776 -0.249474 -0.330327 -0.518981
#
#           DATA_6    DATA_7  Label
# 0      -0.706000 -0.603419      0
# 1      -0.706000 -0.603419      0
# 2      -0.312796  1.816359      0
# 3      -0.302966 -0.603419      0
# 4      -0.706000 -0.603419      0
# ...          ...       ...    ...
# 985745  0.650554 -0.263450      5
# 985746  0.650554 -0.263450      5
# 985747  0.650554 -0.263450      5
# 985748  0.650554 -0.263450      5
# 985749  0.650554 -0.263450      5
#
# [985750 rows x 10 columns]

# %% [markdown]
# ## Feature Selection Algorithm

# %%
correlation_matrix_ids = data_scaled_frame.corr()
nan_features = []
linear_features = []
non_linear_features = []

sample_dataframe = data_scaled_frame.copy(deep=True)

l = correlation_matrix_ids["Label"].sort_values(ascending=False)
pearson_values = []
for name, score in l.items():
    if (name!='Label'):
      pearson_values.append(score)

# %%
from scipy.stats import spearmanr, kendalltau

spearman_values = data_scaled_frame.corr(method='spearman')["Label"].sort_values(ascending=False)
kendall_values = data_scaled_frame.corr(method='kendall')["Label"].sort_values(ascending=False)

# %%
import math
s_values = []
k_values = []

for name,score in spearman_values.items():
     if (name!='Label'):
       s_values.append(score)

for name,score in kendall_values.items():
     if (name!='Label'):
       k_values.append(score)

col_headings = ['Pearson', 'Spearman', 'Kendall']
combined_lists = [pearson_values, s_values, k_values]

# %%
combined_lists
# Out:
# [[-0.053456807010250955,
#   -0.07527368286445722,
#   -0.08000071795254325,
#   -0.11007931847403998,
#   -0.11331636885243568,
#   -0.11786661121857978,
#   -0.1450067214688871,
#   -0.18712745542832465,
#   -0.18743405967994006],
#  [0.14359239513109395,
#   0.12909232770007525,
#   0.041324582423146045,
#   0.029432320144840318,
#   -0.026346608034188163,
#   -0.029447102771695342,
#   -0.038815214806712725,
#   -0.07365375196840698,
#   -0.2880673116547031],
#  [0.13415220236520642,
#   0.12446881830217049,
#   0.03610380986669328,
#   0.027832375171357032,
#   -0.02191931414819543,
#   -0.02261525320248107,
#   -0.035830659127395775,
#   -0.0651993301430398,
#   -0.2314483719580409]]

# %%
import numpy as np
from scipy.stats import entropy
from scipy.signal import gauss_spline, hilbert

# %%
cols = data_scaled_frame.columns
max_amplitude = []

mean_amplitude = []
h_max_amp = []
h_mean_amp = []
h_ph_max = []



for i in cols:
  if (i=='Label'):
    continue

  vals = data_scaled_frame[i].values
  fourier = np.fft.fft(vals)
  amps = np.abs(fourier)
  phase = np.angle(fourier)

  hil_space = hilbert(vals)
  amps_h = np.abs(hil_space)
  phase_h = np.angle(hil_space)

  h_max_amp.append(np.max(amps_h))
  h_mean_amp.append(np.mean(amps_h))
  h_ph_max.append(np.max(phase_h))

  max_amplitude.append(np.max(amps))
  mean_amplitude.append(np.mean(amps))

# %%
combined_lists.extend([gauss_spline(max_amplitude, 3), gauss_spline(mean_amplitude, 3), gauss_spline(h_max_amp, 3), gauss_spline(h_mean_amp, 3), gauss_spline(h_ph_max, 3)])

# %%
arr = np.array(combined_lists)

# %%
inter = np.dot(arr.T, arr)

# %%
inter
# Out:
# array([[ 4.64859341e-02,  4.35076718e-02,  1.96487860e-02,
#          1.84572804e-02,  4.51396426e-03,  3.80628150e-03,
#          2.97788366e-03, -5.25059980e-03, -5.74955107e-02],
#        [ 4.35076718e-02,  4.14256585e-02,  1.97455872e-02,
#          1.94601172e-02,  6.79158271e-03,  6.29766515e-03,
#          6.19744199e-03, -8.83758025e-05, -4.77340607e-02],
#        [ 1.96487860e-02,  1.97455872e-02,  1.36232348e-02,
#          1.52558410e-02,  1.19336203e-02,  1.17664053e-02,
#          1.38422996e-02,  1.33024456e-02, -7.75411663e-04],
#        [ 1.84572804e-02,  1.94601172e-02,  1.52558410e-02,
#          1.80030755e-02,  1.58550975e-02,  1.58659068e-02,
#          1.89818444e-02,  2.03606751e-02,  1.02199756e-02],
#        [ 4.51396426e-03,  6.79158271e-03,  1.19336203e-02,
#          1.58550975e-02,  1.93683359e-02,  1.95547681e-02,
#          2.40335372e-02,  2.87790654e-02,  3.89641791e-02],
#        [ 3.80628150e-03,  6.29766515e-03,  1.17664053e-02,
#          1.58659068e-02,  1.95547681e-02,  1.98059234e-02,
#          2.43774247e-02,  2.95695620e-02,  4.04683195e-02],
#        [ 2.97788366e-03,  6.19744199e-03,  1.38422996e-02,
#          1.89818444e-02,  2.40335372e-02,  2.43774247e-02,
#          3.00882949e-02,  3.68807597e-02,  5.21323537e-02],
#        [-5.25059980e-03, -8.83758025e-05,  1.33024456e-02,
#          2.03606751e-02,  2.87790654e-02,  2.95695620e-02,
#          3.68807597e-02,  4.79953296e-02,  7.53577389e-02],
#        [-5.74955107e-02, -4.77340607e-02, -7.75411663e-04,
#          1.02199756e-02,  3.89641791e-02,  4.04683195e-02,
#          5.21323537e-02,  7.53577389e-02,  1.76469436e-01]])

# %%
eigen_values, eigen_vectors = np.linalg.eig(inter)

# %%
eigen_values
# Out:
# array([ 2.76603206e-01+0.0000000e+00j,  1.34900334e-01+0.0000000e+00j,
#         1.55805002e-03+0.0000000e+00j,  2.03632503e-04+0.0000000e+00j,
#         1.82275004e-15+0.0000000e+00j,  1.28006142e-17+0.0000000e+00j,
#        -1.84772992e-18+1.9967852e-18j, -1.84772992e-18-1.9967852e-18j,
#         5.69714204e-18+0.0000000e+00j])

# %%
eigen_vectors = np.abs(eigen_vectors).tolist()

# %%
eigen_vectors_arr = np.array(eigen_vectors)

# %%
eigen_vectors_arr = np.mean(eigen_vectors_arr, axis=0)

# %%
eigen_vectors = eigen_vectors_arr.tolist()

# %%
eigen_vectors
# Out:
# [0.2581612157778578,
#  0.31478639166127137,
#  0.2563784675192566,
#  0.2814732419901687,
#  0.22745071718115678,
#  0.27095475552458703,
#  0.2564166079786054,
#  0.2564166079786054,
#  0.24732406540883925]

# %%
np.mean(eigen_vectors)
# Out:
# np.float64(0.2632624523355942)

# %%
thrs = np.mean(eigen_vectors)

# %%
feature_indices_selected = []
for i in range(0, len(eigen_vectors)):
  if eigen_vectors[i]>=thrs:
    feature_indices_selected.append(i)

# %%
columns = np.array(list(data_scaled_frame.columns))

# %%
selected_features = columns[feature_indices_selected]

# %%
selected_features = selected_features.tolist()

# %%
selected_features
# Out:
# ['DATA_0', 'DATA_2', 'DATA_4']

# %%
final_clean = data_scaled_frame

# %% [markdown]
# ## Mutual Information Gain - Part of Feature Selection Algorithm

# %%
from sklearn.feature_selection import mutual_info_classif

info_gain = mutual_info_classif(final_clean, final_clean['Label'])

# %%
scores = pd.DataFrame({'feature':final_clean.columns, 'score':info_gain})

scores = scores.sort_values(by = 'score', ascending=False)

# %%
scores
# Out:
#   feature     score
# 9   Label  0.573648
# 0      ID  0.551876
# 4  DATA_3  0.532005
# 1  DATA_0  0.474431
# 2  DATA_1  0.473779
# 8  DATA_7  0.446952
# 7  DATA_6  0.420151
# 5  DATA_4  0.417277
# 3  DATA_2  0.385780
# 6  DATA_5  0.371394

# %%
final_info_gain = []
for i in range(len(list(scores['feature']))):
    if i!=0:
        if list(scores['score'])[i] > thrs and (list(scores['feature'])[i] != 'ID'):
            final_info_gain.append(list(scores['feature'])[i])
print(final_info_gain)
print(len(final_info_gain))
# Out:
# ['DATA_3', 'DATA_0', 'DATA_1', 'DATA_7', 'DATA_6', 'DATA_4', 'DATA_2', 'DATA_5']
# 8

# %%
# Number of features selected.
print(len(final_info_gain))
# Out:
# 8

# %%
final_info_gain.extend(selected_features)

# %% [markdown]
# ## Selected Features

# %%
final_info_gain = list(set(final_info_gain))

# %%
len(final_info_gain)
# Out:
# 8

# %%
final_info_gain
# Out:
# ['DATA_2',
#  'DATA_3',
#  'DATA_4',
#  'DATA_1',
#  'DATA_6',
#  'DATA_0',
#  'DATA_7',
#  'DATA_5']

# %% [markdown]
# ## XGBoost Model

# %%
X_Selected = final_clean[final_info_gain]

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import mean_absolute_error

# %%
X_train, X_test, y_train, y_test = train_test_split(X_Selected, final_clean['Label'] , test_size = 0.3, random_state=42)

# %%
y_train.value_counts()
# Out:
# Label
# 0    599581
# 1     36541
# 3     26985
# 4     12223
# 5      9818
# 2      4877
# Name: count, dtype: int64

# %%
import xgboost
import time

# %%
from sklearn.metrics import mean_absolute_error

# %%
xg = xgboost.XGBClassifier(objective='multi:softmax', num_class = 6)

s_t = time.time()
xg.fit(X_train, y_train)
e_t = time.time()

# %%
total = e_t - s_t
total
# Out:
# 31.961788654327393

# %%
y_pred_xg = xg.predict(X_test)

# %%
acc_xg = accuracy_score(y_test, y_pred_xg)

# %%
acc_xg
# Out:
# 0.9963547214472905

# %%
error = mean_absolute_error(y_test, y_pred_xg)
print("Mean Absolute Error = ", error)
# Out:
# Mean Absolute Error =  0.0036926198326147604

# %%
xg.get_booster().get_score(importance_type = 'weight')
# Out:
# {'DATA_2': 382.0,
#  'DATA_3': 302.0,
#  'DATA_4': 285.0,
#  'DATA_1': 339.0,
#  'DATA_6': 351.0,
#  'DATA_0': 297.0,
#  'DATA_7': 247.0,
#  'DATA_5': 117.0}

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix_xg = confusion_matrix(y_test, y_pred_xg)

# %%
import matplotlib.pyplot as plt
import seaborn
plt.figure(figsize=(7,7))
seaborn.heatmap(confusion_matrix_xg, annot=True, cmap="Reds", xticklabels=['5', '4', '3', '2', '1', '0'], yticklabels=['5', '4', '3', '2', '1', '0'])
plt.show()

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred_xg, output_dict=True)

# %%
report
# Out:
# {'0': {'precision': 0.9999766573295985,
#   'recall': 1.0,
#   'f1-score': 0.9999883285285776,
#   'support': 257034.0},
#  '1': {'precision': 1.0,
#   'recall': 0.9999363989060612,
#   'f1-score': 0.9999681984417237,
#   'support': 15723.0},
#  '2': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2116.0},
#  '3': {'precision': 0.9143359437430079,
#   'recall': 0.999737876802097,
#   'f1-score': 0.955131683292291,
#   'support': 11445.0},
#  '4': {'precision': 1.0,
#   'recall': 0.7954979015642885,
#   'f1-score': 0.8861028474288143,
#   'support': 5242.0},
#  '5': {'precision': 1.0,
#   'recall': 0.9995198079231693,
#   'f1-score': 0.9997598463016331,
#   'support': 4165.0},
#  'accuracy': 0.9963547214472905,
#  'macro avg': {'precision': 0.9857187668454345,
#   'recall': 0.9657819975326026,
#   'f1-score': 0.9734918173321733,
#   'support': 295725.0},
#  'weighted avg': {'precision': 0.996664384195434,
#   'recall': 0.9963547214472905,
#   'f1-score': 0.9962293787148943,
#   'support': 295725.0}}

# %% [markdown]
# ## Random Forest Model

# %%
rf = RandomForestClassifier(n_estimators = 100, random_state=42)
s_t = time.time()
rf.fit(X_train, y_train)
e_t = time.time()

total = e_t - s_t

# %%
print("total time = ", total)
# Out:
# total time =  45.08191394805908

# %%
y_pred = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.9963547214472905

# %%
mae_error_rf = mean_absolute_error(y_test, y_pred)
mae_error_rf
# Out:
# 0.0036926198326147604

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred, output_dict=True)

# %%
report
# Out:
# {'0': {'precision': 0.9999766573295985,
#   'recall': 1.0,
#   'f1-score': 0.9999883285285776,
#   'support': 257034.0},
#  '1': {'precision': 1.0,
#   'recall': 0.9999363989060612,
#   'f1-score': 0.9999681984417237,
#   'support': 15723.0},
#  '2': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2116.0},
#  '3': {'precision': 0.9143359437430079,
#   'recall': 0.999737876802097,
#   'f1-score': 0.955131683292291,
#   'support': 11445.0},
#  '4': {'precision': 1.0,
#   'recall': 0.7954979015642885,
#   'f1-score': 0.8861028474288143,
#   'support': 5242.0},
#  '5': {'precision': 1.0,
#   'recall': 0.9995198079231693,
#   'f1-score': 0.9997598463016331,
#   'support': 4165.0},
#  'accuracy': 0.9963547214472905,
#  'macro avg': {'precision': 0.9857187668454345,
#   'recall': 0.9657819975326026,
#   'f1-score': 0.9734918173321733,
#   'support': 295725.0},
#  'weighted avg': {'precision': 0.996664384195434,
#   'recall': 0.9963547214472905,
#   'f1-score': 0.9962293787148943,
#   'support': 295725.0}}

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix_rn = confusion_matrix(y_test, y_pred)

# %%
import matplotlib.pyplot as plt
import seaborn
plt.figure(figsize=(7,7))
seaborn.heatmap(confusion_matrix_rn, annot=True, cmap="Reds", xticklabels=['5', '4', '3', '2', '1', '0'], yticklabels=['5', '4', '3', '2', '1', '0'])
plt.show()

# %% [markdown]
# ## CatBoost

# %%
pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.1.2)
# Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.1 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8

# %%
from catboost import CatBoostClassifier

# %%
cb = CatBoostClassifier(iterations=2000, loss_function = 'MultiClass')

# %%
s_t = time.time()
cb.fit(X_train, y_train)
e_t = time.time()
total = e_t - s_t
# Out:
# Learning rate set to 0.06148
# 0:	learn: 1.5130425	total: 1.1s	remaining: 36m 32s
# 1:	learn: 1.3180895	total: 2.15s	remaining: 35m 44s
# 2:	learn: 1.1636458	total: 3.53s	remaining: 39m 8s
# 3:	learn: 1.0406716	total: 5.17s	remaining: 42m 57s
# 4:	learn: 0.9395416	total: 6.68s	remaining: 44m 27s
# 5:	learn: 0.8527218	total: 7.83s	remaining: 43m 21s
# 6:	learn: 0.7789801	total: 8.83s	remaining: 41m 55s
# 7:	learn: 0.7136098	total: 10s	remaining: 41m 39s
# 8:	learn: 0.6555332	total: 11.2s	remaining: 41m 21s
# 9:	learn: 0.6045878	total: 12.2s	remaining: 40m 25s
# 10:	learn: 0.5592168	total: 13.6s	remaining: 41m 6s
# 11:	learn: 0.5186171	total: 14.7s	remaining: 40m 37s
# 12:	learn: 0.4791497	total: 15.8s	remaining: 40m 13s
# 13:	learn: 0.4447471	total: 16.8s	remaining: 39m 48s
# 507:	learn: 0.0050755	total: 5m 17s	remaining: 15m 33s
# 508:	learn: 0.0050754	total: 5m 18s	remaining: 15m 32s
# 509:	learn: 0.0050754	total: 5m 18s	remaining: 15m 31s
# 510:	learn: 0.0050753	total: 5m 19s	remaining: 15m 30s
# 511:	learn: 0.0050752	total: 5m 19s	remaining: 15m 29s
# 512:	learn: 0.0050752	total: 5m 20s	remaining: 15m 28s
# 513:	learn: 0.0050751	total: 5m 20s	remaining: 15m 27s
# 514:	learn: 0.0050751	total: 5m 21s	remaining: 15m 26s
# 515:	learn: 0.0050750	total: 5m 22s	remaining: 15m 26s
# 516:	learn: 0.0050749	total: 5m 22s	remaining: 15m 26s
# 517:	learn: 0.0050749	total: 5m 23s	remaining: 15m 26s
# 518:	learn: 0.0050748	total: 5m 24s	remaining: 15m 26s
# 519:	learn: 0.0050748	total: 5m 25s	remaining: 15m 26s
# 520:	learn: 0.0050747	total: 5m 26s	remaining: 15m 25s
# 521:	learn: 0.0050747	total: 5m 26s	remaining: 15m 24s
# 522:	learn: 0.0050746	total: 5m 27s	remaining: 15m 23s
# 523:	learn: 0.0050745	total: 5m 27s	remaining: 15m 22s
# 524:	learn: 0.0050744	total: 5m 28s	remaining: 15m 21s
# 525:	learn: 0.0050744	total: 5m 28s	remaining: 15m 20s
# 526:	learn: 0.0050743	total: 5m 29s	remaining: 15m 19s
# 527:	learn: 0.0050743	total: 5m 29s	remaining: 15m 18s
# 528:	learn: 0.0050742	total: 5m 30s	remaining: 15m 17s
# 529:	learn: 0.0050742	total: 5m 30s	remaining: 15m 16s
# 530:	learn: 0.0050741	total: 5m 31s	remaining: 15m 15s
# 531:	learn: 0.0050740	total: 5m 31s	remaining: 15m 15s
# 532:	learn: 0.0050740	total: 5m 32s	remaining: 15m 14s
# 533:	learn: 0.0050740	total: 5m 32s	remaining: 15m 13s
# 534:	learn: 0.0050739	total: 5m 33s	remaining: 15m 12s
# 535:	learn: 0.0050739	total: 5m 33s	remaining: 15m 11s
# 536:	learn: 0.0050738	total: 5m 34s	remaining: 15m 10s
# 537:	learn: 0.0050738	total: 5m 34s	remaining: 15m 9s
# 538:	learn: 0.0050737	total: 5m 35s	remaining: 15m 8s
# 539:	learn: 0.0050736	total: 5m 35s	remaining: 15m 7s
# 540:	learn: 0.0050736	total: 5m 36s	remaining: 15m 7s
# 541:	learn: 0.0050736	total: 5m 37s	remaining: 15m 7s
# 542:	learn: 0.0050735	total: 5m 38s	remaining: 15m 7s
# 543:	learn: 0.0050735	total: 5m 38s	remaining: 15m 7s
# 544:	learn: 0.0050734	total: 5m 39s	remaining: 15m 7s
# 545:	learn: 0.0050733	total: 5m 40s	remaining: 15m 6s
# 546:	learn: 0.0050733	total: 5m 40s	remaining: 15m 5s
# 547:	learn: 0.0050733	total: 5m 41s	remaining: 15m 4s
# 548:	learn: 0.0050732	total: 5m 41s	remaining: 15m 3s
# 549:	learn: 0.0050732	total: 5m 42s	remaining: 15m 2s
# 550:	learn: 0.0050731	total: 5m 42s	remaining: 15m 1s
predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_cb)

# %%
accuracy
# Out:
# 0.9963547214472905

# %%
mae_error_cb = mean_absolute_error(y_test, y_pred_cb)
mae_error_cb
# Out:
# 0.0036926198326147604

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred_cb, output_dict=True)

# %%
report
# Out:
# {'0': {'precision': 0.9999766573295985,
#   'recall': 1.0,
#   'f1-score': 0.9999883285285776,
#   'support': 257034.0},
#  '1': {'precision': 1.0,
#   'recall': 0.9999363989060612,
#   'f1-score': 0.9999681984417237,
#   'support': 15723.0},
#  '2': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2116.0},
#  '3': {'precision': 0.9143359437430079,
#   'recall': 0.999737876802097,
#   'f1-score': 0.955131683292291,
#   'support': 11445.0},
#  '4': {'precision': 1.0,
#   'recall': 0.7954979015642885,
#   'f1-score': 0.8861028474288143,
#   'support': 5242.0},
#  '5': {'precision': 1.0,
#   'recall': 0.9995198079231693,
#   'f1-score': 0.9997598463016331,
#   'support': 4165.0},
#  'accuracy': 0.9963547214472905,
#  'macro avg': {'precision': 0.9857187668454345,
#   'recall': 0.9657819975326026,
#   'f1-score': 0.9734918173321733,
#   'support': 295725.0},
#  'weighted avg': {'precision': 0.996664384195434,
#   'recall': 0.9963547214472905,
#   'f1-score': 0.9962293787148943,
#   'support': 295725.0}}

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix_cb = confusion_matrix(y_test, y_pred_cb)

# %%
import matplotlib.pyplot as plt
import seaborn
plt.figure(figsize=(7,7))
seaborn.heatmap(confusion_matrix_cb, annot=True, cmap="Reds", xticklabels=['5', '4', '3', '2', '1', '0'], yticklabels=['5', '4', '3', '2', '1', '0'])
plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(multi_class='multinomial', max_iter=2000)

# %%
s_t = time.time()
lr.fit(X_train, y_train)
e_t = time.time()

total = e_t - s_t
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(

# %%
print("total time = ", total)
# Out:
# total time =  70.25226831436157

# %%
y_pred_lr = lr.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_lr)

# %%
accuracy
# Out:
# 0.8754822892890354

# %%
mae_error_lr = mean_absolute_error(y_test, y_pred_lr)
mae_error_lr
# Out:
# 0.24978611886042776

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred_lr, output_dict=True)

# %%
report
# Out:
# {'0': {'precision': 0.8919131518063712,
#   'recall': 0.9749021530225573,
#   'f1-score': 0.931563020461575,
#   'support': 257034.0},
#  '1': {'precision': 0.00018178512997636792,
#   'recall': 6.360109393881575e-05,
#   'f1-score': 9.423294383716548e-05,
#   'support': 15723.0},
#  '2': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2116.0},
#  '3': {'precision': 0.8126743722598645,
#   'recall': 0.1781564001747488,
#   'f1-score': 0.29224595098179734,
#   'support': 11445.0},
#  '4': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 5242.0},
#  '5': {'precision': 0.9751698289997658,
#   'recall': 0.9995198079231693,
#   'f1-score': 0.9871946881669433,
#   'support': 4165.0},
#  'accuracy': 0.8754822892890354,
#  'macro avg': {'precision': 0.6133231896993296,
#   'recall': 0.5254403270357356,
#   'f1-score': 0.5351829820923588,
#   'support': 295725.0},
#  'weighted avg': {'precision': 0.8275712361054887,
#   'recall': 0.8754822892890354,
#   'f1-score': 0.8420568832905517,
#   'support': 295725.0}}

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix_lr = confusion_matrix(y_test, y_pred_lr)

# %%
import matplotlib.pyplot as plt
import seaborn
plt.figure(figsize=(7,7))
seaborn.heatmap(confusion_matrix_lr, annot=True, cmap="Reds", xticklabels=['5', '4', '3', '2', '1', '0'], yticklabels=['5', '4', '3', '2', '1', '0'])
plt.show()
